# %%
# dzięki temu będziemy mogli rysować wykresy "inline", tzn. bezpośrednio w notebooku.
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(3,5))

plt.plot([100,200,300,400],[0.1,0.2,0.8,0.9])
plt.show()
plt.savefig('myplot.pdf')
plt.close()
