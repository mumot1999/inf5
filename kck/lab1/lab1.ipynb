# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
import matplotlib as mpl

mpl.rcParams['figure.figsize'] = (13,6)

# %%
class File:
    def __init__(self, file_name, name):
        self.name = name
        self.file_name = file_name
        self.data = pd.read_csv(file_name)

# Load data
data = (
    pd.read_csv('pliki/cel-rs.csv'),
    pd.read_csv('pliki/cel.csv'),
    pd.read_csv('pliki/rsel.csv'),
    pd.read_csv('pliki/2cel.csv'),
    pd.read_csv('pliki/2cel-rs.csv')
)

# %%
# Series

# columns.reset_index(inplace=True)

for datum in data:
    # columns = datum.filter(regex=("run\-.*")).T.rename(index=lambda x: int(x[4:])).sort_index()
    to_plot = datum.filter(regex=("run\-.*")).mean(axis=1)
    ts = pd.Series(to_plot)
    # ts = ts.cumsum()
    ts.plot()
