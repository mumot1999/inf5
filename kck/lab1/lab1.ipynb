# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
import matplotlib as mpl

mpl.rcParams['figure.figsize'] = (8, 8)

# %%
class File:
    def __init__(self, file_name, name):
        self.name = name
        self.file_name = file_name
        self.data = pd.read_csv(file_name)

# Load data
data = (
    File('pliki/cel-rs.csv', 'CEL-RS'),
    File('pliki/cel.csv', 'CEL'),
    File('pliki/rsel.csv', 'RSEL'),
    File('pliki/2cel.csv', '2CEL'),
    File('pliki/2cel-rs.csv', '2CEL-RS'),
)

# %%
for datum in data:
    to_plot = datum.data.filter(regex=("run\-.*")).mean(axis=1)
    plt.plot(to_plot.index, to_plot.values, label=datum.name)
    
plt.xlabel("Pokolenie")
plt.ylabel("Odsetek wygranych gier")
plt.margins(0)
plt.figlegend(loc='lower right', bbox_to_anchor=(0.89, 0.13))
plt.savefig('zad1.pdf', dpi=1)
