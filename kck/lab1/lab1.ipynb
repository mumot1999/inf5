# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
import matplotlib as mpl

mpl.rcParams['figure.figsize'] = (8, 8)

# %%
class File:
    def __init__(self, file_name, name, color=None):
        self.color = color
        self.name = name
        self.file_name = file_name
        self.data = pd.read_csv(file_name)

# Load data
data = (
    File('pliki/rsel.csv', '1-Evol-RS', '#1010ff'),
    File('pliki/cel-rs.csv', '1-Coev-RS', '#008000'),
    File('pliki/2cel-rs.csv', '2-Coev-RS', '#ff0202'),
    File('pliki/cel.csv', '1-Coev', 'black'),
    File('pliki/2cel.csv', '2-Coev', '#ff04ff'),
)

# %%
for datum in data:
    to_plot = datum.data.filter(regex=("run\-.*")).mean(axis=1)
    plt.plot(to_plot.index, to_plot.values, label=datum.name, color=datum.color)
    
plt.xlabel("Pokolenie")
plt.ylabel("Odsetek wygranych gier")
plt.margins(0)
plt.figlegend(loc='lower right', bbox_to_anchor=(0.89, 0.13))

plt.savefig('zad1.pdf', dpi=1)
